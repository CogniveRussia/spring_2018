# %% [markdown]
# ### Imports

# %%
import os
import pickle
import IPython
import sklearn
import numpy as np
import kmapper as km
import pandas as pd
import seaborn as sns
from umap import UMAP
import tqdm

from sklearn import cluster, preprocessing, manifold, decomposition
from sklearn.model_selection import StratifiedKFold, KFold
from scipy.spatial import distance
from scipy.sparse import issparse
from datetime import datetime
from collections import defaultdict
from datetime import datetime
import inspect
import itertools
import sys
import warnings

from sklearn.manifold import t_sne, isomap

from sklearn import datasets
from sklearn.cluster import DBSCAN

from sklearn.decomposition import TruncatedSVD
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib inline
sns.set(style='white', rc={'figure.figsize':(12,8)})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-662be7751635> in <module>()
#       7 import pandas as pd
#       8 import seaborn as sns
# ----> 9 from umap import UMAP
#      10 import tqdm
#      11
#
# ModuleNotFoundError: No module named 'umap'

# %% [markdown]
# ### Some tweaks to kmapper (remove forced index column adding to original data)

# %%
class CustomMapper(km.KeplerMapper):
    def map(self,
            projected_X,
            inverse_X=None,
            clusterer=cluster.DBSCAN(eps=0.5, min_samples=3),
            nr_cubes=None,
            overlap_perc=None,
            coverer=km.Cover(nr_cubes=10, overlap_perc=0.1),
            nerve=km.GraphNerve()):
        """Apply Mapper algorithm on this projection and build a simplicial complex. Returns a dictionary with nodes and links.
        Parameters
        ----------
        projected_X : Numpy Array
            Output from fit_transform
        inverse_X : Numpy Array
            Original data. If `None`, then use `projected_X` for clustering.
        clusterer:
            Scikit-learn API compatible clustering algorithm. Default: DBSCAN
        nr_cubes : Int
            The number of intervals/hypercubes to create. Default = 10. (DeprecationWarning: define Cover explicitly in future versions)
        overlap_perc : Float
            The percentage of overlap "between" the intervals/hypercubes. Default = 0.1. (DeprecationWarning: define Cover explicitly in future versions)
        coverer : kmapper.Cover
            Cover scheme for lens. Instance of kmapper.cover providing methods `define_bins` and `find_entries`.
        nerve : kmapper.Nerve
            Nerve builder implementing `__call__(nodes)` API
        Returns
        =======
        simplicial_complex : dict
            A dictionary with "nodes", "links" and "meta" information.
        Example
        =======
        >>> simplicial_complex = mapper.map(projected_X, inverse_X=None, clusterer=cluster.DBSCAN(eps=0.5,min_samples=3),nr_cubes=10, overlap_perc=0.1)
        >>>print(simplicial_complex["nodes"])
        >>>print(simplicial_complex["links"])
        >>>print(simplicial_complex["meta"])
        """

        start = datetime.now()

        nodes = defaultdict(list)
        meta = defaultdict(list)
        graph = {}

        # If inverse image is not provided, we use the projection as the inverse image (suffer projection loss)
        if inverse_X is None:
            inverse_X = projected_X

        if nr_cubes is not None or overlap_perc is not None:
            # If user supplied nr_cubes or overlap_perc,
            # use old defaults instead of new Cover
            nr_cubes = nr_cubes if nr_cubes else 10
            overlap_perc = overlap_perc if overlap_perc else 0.1
            self.coverer = km.Cover(nr_cubes=nr_cubes,
                                 overlap_perc=overlap_perc)

            warnings.warn(
                "Explicitly passing in nr_cubes and overlap_perc will be deprecated in future releases. Please supply Cover object.", DeprecationWarning)
        else:
            self.coverer = coverer

        if self.verbose > 0:
            print("Mapping on data shaped %s using lens shaped %s\n" %
                  (str(inverse_X.shape), str(projected_X.shape)))

        # Prefix'ing the data with ID's
        ids = np.array([x for x in range(projected_X.shape[0])])
        projected_X = np.c_[ids, projected_X]
        inverse_X = inverse_X

        # Cover scheme defines a list of elements
        bins = self.coverer.define_bins(projected_X)

        # Algo's like K-Means, have a set number of clusters. We need this number
        # to adjust for the minimal number of samples inside an interval before
        # we consider clustering or skipping it.
        cluster_params = clusterer.get_params()
        min_cluster_samples = cluster_params.get("n_clusters", 1)

        if self.verbose > 1:
            print("Minimal points in hypercube before clustering: %d" %
                  (min_cluster_samples))

        # Subdivide the projected data X in intervals/hypercubes with overlap
        if self.verbose > 0:
            bins = list(bins)  # extract list from generator
            total_bins = len(bins)
            print("Creating %s hypercubes." % total_bins)

        for i, cube in enumerate(bins):
            # Slice the hypercube:
            #  gather all entries in this element of the cover
            hypercube = self.coverer.find_entries(projected_X, cube)

            if self.verbose > 1:
                print("There are %s points in cube_%s / %s" %
                      (hypercube.shape[0], i, total_bins))

            # If at least min_cluster_samples samples inside the hypercube
            if hypercube.shape[0] >= min_cluster_samples:

                # Cluster the data point(s) in the cube, skipping the id-column
                # Note that we apply clustering on the inverse image (original data samples) that fall inside the cube.
                inverse_x = inverse_X[[int(nn) for nn in hypercube[:, 0]]]

                clusterer.fit(inverse_x)

                if self.verbose > 1:
                    print("Found %s clusters in cube_%s\n" % (
                        np.unique(clusterer.labels_[clusterer.labels_ > -1]).shape[0], i))

                # TODO: I think this loop could be improved by turning inside out:
                #           - partition points according to each cluster
                # Now for every (sample id in cube, predicted cluster label)
                for a in np.c_[hypercube[:, 0], clusterer.labels_]:
                    if a[1] != -1:  # if not predicted as noise

                        # TODO: allow user supplied label
                        #   - where all those extra values necessary?
                        cluster_id = "cube{}_cluster{}".format(i, int(a[1]))

                        # Append the member id's as integers
                        nodes[cluster_id].append(int(a[0]))
                        meta[cluster_id] = {
                            "size": hypercube.shape[0], "coordinates": cube}
            else:
                if self.verbose > 1:
                    print("Cube_%s is empty.\n" % (i))

        links, simplices = nerve(nodes)

        graph["nodes"] = nodes
        graph["links"] = links
        graph["simplices"] = simplices
        graph["meta_data"] = {
            "projection": self.projection if self.projection else "custom",
            "nr_cubes": self.coverer.nr_cubes,
            "overlap_perc": self.coverer.overlap_perc,
            "clusterer": str(clusterer),
            "scaler": str(self.scaler)
        }
        graph["meta_nodes"] = meta

        # Reporting
        if self.verbose > 0:
            self._summary(graph, str(datetime.now() - start))

        return graph

    def _summary(self, graph, time):
        # TODO: this summary is relevant to the type of Nerve being built.
        links = graph["links"]
        nodes = graph["nodes"]
        nr_links = sum(len(v) for k, v in links.items())

        print("\nCreated %s edges and %s nodes in %s." %
              (nr_links, len(nodes), time))

# %% [markdown]
# ### MetaKMeans class can estimate n_clusters based on a number of observations

# %%
class MetaKMeans(sklearn.base.BaseEstimator, sklearn.base.ClusterMixin, sklearn.base.TransformerMixin):
    def __init__(self,
                 init='k-means++',
                 n_init=10,
                 max_iter=300,
                 tol=0.0001,
                 precompute_distances='auto',
                 verbose=0,
                 random_state=None,
                 copy_x=True,
                 n_jobs=1,
                 algorithm='auto'):
        self.init = init
        self.n_init = n_init
        self.max_iter = max_iter
        self.tol = tol
        self.precompute_distances = precompute_distances
        self.verbose = verbose
        self.random_state = random_state
        self.copy_x = copy_x
        self.n_jobs = n_jobs
        self.algorithm = algorithm
        self._temp_clusterer = None
    
    def get_params(self, deep=True):
        params = {
            'init': self.init,
            'n_init': self.n_init,
            'max_iter': self.max_iter,
            'tol': self.tol,
            'precompute_distances': self.precompute_distances,
            'verbose': self.verbose,
            'random_state': self.random_state,
            'copy_x': self.copy_x,
            'n_jobs': self.n_jobs,
            'algorithm': self.algorithm
        }
        return params
    
    def _estimate_n_clusters(self, n):
        return max(1, int(np.log1p(n)) // 2)

    def fit(self, X, y=None):
        n_clusters = self._estimate_n_clusters(len(X))
        self._temp_clusterer = sklearn.cluster.KMeans(n_clusters=n_clusters, **self.get_params())
        self._temp_clusterer.fit(X, y)
        self.labels_ = self._temp_clusterer.labels_.copy()

    def fit_predict(self, X, y=None):
        self.fit(X, y)
        return self.labels_

# %% [markdown]
# ### Displaying html inside notebook cell

# %%
def display(path_html):
    """ Displays a html file inside a Jupyter Notebook output cell.
    
    Parameters
    ----------
    path_html : str
        Path to html. Use file name for file inside current working 
        directory. Use `file://` browser url-format for path to local file.
        Use `https://` urls for externally hosted resources.

    Notes
    -----
    Thanks to https://github.com/smartinsightsfromdata for the issue:
    https://github.com/MLWave/kepler-mapper/issues/10

    """

    iframe = '<iframe src=' + path_html \
            + ' width=100%% height=800 frameBorder="0"></iframe>'
    IPython.core.display.display(IPython.core.display.HTML(iframe))

# %% [markdown]
# ### Read serialized dataset
# * graph_trans_df --- dataframes that contains fraud labels information for each transaction
# * baseamount_agg_mean_values --- aggregated features (data where clusteting will take place)
# * pca_mean_transformed --- 2d pca of aggregated features
# * isof_scores_off_ops --- isolation forest scores for each sample
# * mean_colnames_selected --- names for aggregated features

# %%
with open('tda_isof_pca_dataset_sample.pkl', 'rb') as handle:
    tda_isof_pca_dataset_sample = pickle.load(handle)

# %%
graph_trans_df = tda_isof_pca_dataset_sample['graph_trans_df']
baseamount_agg_mean_values = tda_isof_pca_dataset_sample['baseamount_agg_mean_values']
pca_mean_transformed = tda_isof_pca_dataset_sample['pca_mean_transformed']
isof_scores_off_ops = tda_isof_pca_dataset_sample['isof_scores_off_ops']
mean_colnames_selected = tda_isof_pca_dataset_sample['mean_colnames_selected']

labels = graph_trans_df[('all', 'target')].values

# %% [markdown]
# ### concatenate pca output and isolation forest scores into a 3d projection

# %%
proj_3d = np.c_[pca_mean_transformed, isof_scores_off_ops]

# %%
# Initialize
mapper = CustomMapper(verbose=2)

# %% [markdown]
# ### Create graph with Mapper algorithm

# %%
# Create dictionary called 'graph' with nodes, edges and meta-information
graph = mapper.map(proj_3d, baseamount_agg_mean_values, clusterer=MetaKMeans(n_jobs=10), nr_cubes=15, overlap_perc=0.2)
# Out:
# /home/const.belev/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:58: DeprecationWarning: Explicitly passing in nr_cubes and overlap_perc will be deprecated in future releases. Please supply Cover object.
# Mapping on data shaped (821659, 782) using lens shaped (821659, 3)
#
# Minimal points in hypercube before clustering: 1
# Creating 3375 hypercubes.
# There are 0 points in cube_0 / 3375
# Cube_0 is empty.
#
# There are 0 points in cube_1 / 3375
# Cube_1 is empty.
#
# There are 0 points in cube_2 / 3375
# Cube_2 is empty.
#
# There are 0 points in cube_3 / 3375
# Cube_3 is empty.
#
# There are 0 points in cube_4 / 3375
# Cube_4 is empty.
#
# There are 0 points in cube_5 / 3375
# Cube_5 is empty.
#
# There are 0 points in cube_6 / 3375
# Cube_6 is empty.
#
# There are 0 points in cube_7 / 3375
# Cube_7 is empty.
#
# There are 0 points in cube_8 / 3375
# Cube_8 is empty.
#
# There are 0 points in cube_9 / 3375
# Cube_9 is empty.
#
# There are 0 points in cube_10 / 3375
# Cube_10 is empty.
#
# There are 0 points in cube_11 / 3375
# Cube_11 is empty.
#
# There are 0 points in cube_12 / 3375
# Cube_12 is empty.
#
# There are 0 points in cube_13 / 3375
# Cube_13 is empty.
#
# There are 0 points in cube_14 / 3375
# Cube_14 is empty.
#
# There are 0 points in cube_15 / 3375
# Cube_15 is empty.
#
# There are 0 points in cube_16 / 3375
# Cube_16 is empty.
#
# There are 0 points in cube_17 / 3375
# Cube_17 is empty.
#
# There are 0 points in cube_18 / 3375
# Cube_18 is empty.
#
# There are 0 points in cube_19 / 3375
# Cube_19 is empty.
#
# There are 0 points in cube_20 / 3375
# Cube_20 is empty.
#
# There are 0 points in cube_21 / 3375
# Cube_21 is empty.
#
# There are 0 points in cube_22 / 3375
# Cube_22 is empty.
#
# There are 0 points in cube_23 / 3375
# Cube_23 is empty.
#
# There are 0 points in cube_24 / 3375
# Cube_24 is empty.
#
# There are 0 points in cube_25 / 3375
# Cube_25 is empty.
#
# There are 0 points in cube_26 / 3375
# Cube_26 is empty.
#
# There are 0 points in cube_27 / 3375
# Cube_27 is empty.
#
# There are 0 points in cube_28 / 3375
# Cube_28 is empty.
#
# There are 0 points in cube_29 / 3375
# Cube_29 is empty.
#
# There are 0 points in cube_30 / 3375
# Cube_30 is empty.
#
# There are 0 points in cube_31 / 3375
# Cube_31 is empty.
#
# There are 0 points in cube_32 / 3375
# Cube_32 is empty.
#
# There are 0 points in cube_33 / 3375
# Cube_33 is empty.
#
# There are 0 points in cube_34 / 3375
# Cube_34 is empty.
#
# There are 0 points in cube_35 / 3375
# Cube_35 is empty.
#
# There are 0 points in cube_36 / 3375
# Cube_36 is empty.
#
# There are 0 points in cube_37 / 3375
# Cube_37 is empty.
#
# There are 0 points in cube_38 / 3375
# Cube_38 is empty.
#
# There are 0 points in cube_39 / 3375
# Cube_39 is empty.
#
# There are 0 points in cube_40 / 3375
# Cube_40 is empty.
#
# There are 0 points in cube_41 / 3375
# Cube_41 is empty.
#
# There are 0 points in cube_42 / 3375
# Cube_42 is empty.
#
# There are 0 points in cube_43 / 3375
# Cube_43 is empty.
#
# There are 0 points in cube_44 / 3375
# Cube_44 is empty.
#
# There are 0 points in cube_45 / 3375
# Cube_45 is empty.
#
# There are 0 points in cube_46 / 3375
# Cube_46 is empty.
#
# There are 0 points in cube_47 / 3375
# Cube_47 is empty.
#
# There are 0 points in cube_48 / 3375
# Cube_48 is empty.
#
# There are 0 points in cube_49 / 3375
# Cube_49 is empty.
#
# There are 0 points in cube_50 / 3375
# Cube_50 is empty.
#
# There are 0 points in cube_51 / 3375
# Cube_51 is empty.
#
# There are 0 points in cube_52 / 3375
# Cube_52 is empty.
#
# There are 0 points in cube_53 / 3375
# Cube_53 is empty.
#
# There are 0 points in cube_54 / 3375
# Cube_54 is empty.
#
# There are 0 points in cube_55 / 3375
# Cube_55 is empty.
#
# There are 0 points in cube_56 / 3375
# Cube_56 is empty.
#
# There are 0 points in cube_57 / 3375
# Cube_57 is empty.
#
# There are 0 points in cube_58 / 3375
# Cube_58 is empty.
#
# There are 0 points in cube_59 / 3375
# Cube_59 is empty.
#
# There are 0 points in cube_60 / 3375
# Cube_60 is empty.
#
# There are 0 points in cube_61 / 3375
# Cube_61 is empty.
#
# There are 0 points in cube_62 / 3375
# Cube_62 is empty.
#
# There are 0 points in cube_63 / 3375
# Cube_63 is empty.
#
# There are 0 points in cube_64 / 3375
# Cube_64 is empty.
#
# There are 0 points in cube_65 / 3375
# Cube_65 is empty.
#
# There are 0 points in cube_66 / 3375
# Cube_66 is empty.
#
# There are 0 points in cube_67 / 3375
# Cube_67 is empty.
#
# There are 0 points in cube_68 / 3375
# Cube_68 is empty.
#
# There are 0 points in cube_69 / 3375
# Cube_69 is empty.
#
# There are 0 points in cube_70 / 3375
# Cube_70 is empty.
#
# There are 0 points in cube_71 / 3375
# Cube_71 is empty.
#
# There are 0 points in cube_72 / 3375
# Cube_72 is empty.
#
# There are 0 points in cube_73 / 3375
# Cube_73 is empty.
#
# There are 0 points in cube_74 / 3375
# Cube_74 is empty.
#
# There are 0 points in cube_75 / 3375
# Cube_75 is empty.
#
# There are 0 points in cube_76 / 3375
# Cube_76 is empty.
#
# There are 0 points in cube_77 / 3375
# Cube_77 is empty.
#
# There are 0 points in cube_78 / 3375
# Cube_78 is empty.
#
# There are 0 points in cube_79 / 3375
# Cube_79 is empty.
#
# There are 0 points in cube_80 / 3375
# Cube_80 is empty.
#
# There are 0 points in cube_81 / 3375
# Cube_81 is empty.
#
# There are 0 points in cube_82 / 3375
# Cube_82 is empty.
#
# There are 0 points in cube_83 / 3375
# Cube_83 is empty.
#
# There are 0 points in cube_84 / 3375
# Cube_84 is empty.
#
# There are 0 points in cube_85 / 3375
# Cube_85 is empty.
#
# There are 0 points in cube_86 / 3375
# Cube_86 is empty.
#
# There are 0 points in cube_87 / 3375
# Cube_87 is empty.
#
# There are 0 points in cube_88 / 3375
# Cube_88 is empty.
#
# There are 0 points in cube_89 / 3375
# Cube_89 is empty.
#
# There are 0 points in cube_90 / 3375
# Cube_90 is empty.
#
# There are 0 points in cube_91 / 3375
# Cube_91 is empty.
#
# There are 0 points in cube_92 / 3375
# Cube_92 is empty.
#
# There are 0 points in cube_93 / 3375
# Cube_93 is empty.
#
# There are 0 points in cube_94 / 3375
# Cube_94 is empty.
#
# There are 0 points in cube_95 / 3375
# Cube_95 is empty.
#
# There are 0 points in cube_96 / 3375
# Cube_96 is empty.
#
# There are 0 points in cube_97 / 3375
# Cube_97 is empty.
#
# There are 0 points in cube_98 / 3375
# Cube_98 is empty.
#
# There are 0 points in cube_99 / 3375
# Cube_99 is empty.
#
# There are 0 points in cube_100 / 3375
# Cube_100 is empty.
#
# There are 0 points in cube_101 / 3375
# Cube_101 is empty.
#
# There are 0 points in cube_102 / 3375
# Cube_102 is empty.
#
# There are 0 points in cube_103 / 3375
# Cube_103 is empty.
#
# There are 0 points in cube_104 / 3375
# Cube_104 is empty.
#
# There are 5 points in cube_105 / 3375
# Found 1 clusters in cube_105
#
# There are 10 points in cube_106 / 3375
# Found 1 clusters in cube_106
#
# There are 36 points in cube_107 / 3375
# Found 1 clusters in cube_107
#
# There are 110 points in cube_108 / 3375
# Found 2 clusters in cube_108
#
# There are 393 points in cube_109 / 3375
# Found 2 clusters in cube_109
#
# There are 867 points in cube_110 / 3375
# Found 3 clusters in cube_110
#
# There are 1404 points in cube_111 / 3375
# Found 3 clusters in cube_111
#
# There are 2025 points in cube_112 / 3375
# Found 3 clusters in cube_112
#
# There are 3189 points in cube_113 / 3375
# Found 4 clusters in cube_113
#
# There are 4850 points in cube_114 / 3375
# Found 4 clusters in cube_114
#
# There are 7881 points in cube_115 / 3375
# Found 4 clusters in cube_115
#
# There are 12730 points in cube_116 / 3375
# Found 4 clusters in cube_116
#
# There are 22497 points in cube_117 / 3375
# Found 5 clusters in cube_117
#
# There are 47225 points in cube_118 / 3375
# Found 5 clusters in cube_118
#
# There are 307067 points in cube_119 / 3375
# Found 6 clusters in cube_119
#
# There are 27 points in cube_120 / 3375
# Found 1 clusters in cube_120
#
# There are 11 points in cube_121 / 3375
# Found 1 clusters in cube_121
#
# There are 15 points in cube_122 / 3375
# Found 1 clusters in cube_122
#
# There are 39 points in cube_123 / 3375
# Found 1 clusters in cube_123
#
# There are 25 points in cube_124 / 3375
# Found 1 clusters in cube_124
#
# There are 22 points in cube_125 / 3375
# Found 1 clusters in cube_125
#
# There are 20 points in cube_126 / 3375
# Found 1 clusters in cube_126
#
# There are 13 points in cube_127 / 3375
# Found 1 clusters in cube_127
#
# There are 14 points in cube_128 / 3375
# Found 1 clusters in cube_128
#
# There are 13 points in cube_129 / 3375
# Found 1 clusters in cube_129
#
# There are 1 points in cube_130 / 3375
# Found 1 clusters in cube_130
#
# There are 4 points in cube_131 / 3375
# Found 1 clusters in cube_131
#
# There are 2 points in cube_132 / 3375
# Found 1 clusters in cube_132
#
# There are 2 points in cube_133 / 3375
# Found 1 clusters in cube_133
#
# There are 1 points in cube_134 / 3375
# Found 1 clusters in cube_134
#
# There are 0 points in cube_135 / 3375
# Cube_135 is empty.
#
# There are 0 points in cube_136 / 3375
# Cube_136 is empty.
#
# There are 0 points in cube_137 / 3375
# Cube_137 is empty.
#
# There are 0 points in cube_138 / 3375
# Cube_138 is empty.
#
# There are 0 points in cube_139 / 3375
# Cube_139 is empty.
# There are 0 points in cube_140 / 3375
# Cube_140 is empty.
#
# There are 0 points in cube_141 / 3375
# Cube_141 is empty.
#
# There are 1 points in cube_142 / 3375
# Found 1 clusters in cube_142
#
# There are 0 points in cube_143 / 3375
# Cube_143 is empty.
#
# There are 0 points in cube_144 / 3375
# Cube_144 is empty.
#
# There are 0 points in cube_145 / 3375
# Cube_145 is empty.
#
# There are 0 points in cube_146 / 3375
# Cube_146 is empty.
#
# There are 0 points in cube_147 / 3375
# Cube_147 is empty.
#
# There are 0 points in cube_148 / 3375
# Cube_148 is empty.
#
# There are 0 points in cube_149 / 3375
# Cube_149 is empty.
#
# There are 0 points in cube_150 / 3375
# Cube_150 is empty.
#
# There are 0 points in cube_151 / 3375
# Cube_151 is empty.
#
# There are 0 points in cube_152 / 3375
# Cube_152 is empty.
#
# There are 0 points in cube_153 / 3375
# Cube_153 is empty.
#
# There are 0 points in cube_154 / 3375
# Cube_154 is empty.
#
# There are 0 points in cube_155 / 3375
# Cube_155 is empty.
#
# There are 0 points in cube_156 / 3375
# Cube_156 is empty.
#
# There are 0 points in cube_157 / 3375
# Cube_157 is empty.
#
# There are 0 points in cube_158 / 3375
# Cube_158 is empty.
#
# There are 0 points in cube_159 / 3375
# Cube_159 is empty.
#
# There are 0 points in cube_160 / 3375
# Cube_160 is empty.
#
# There are 0 points in cube_161 / 3375
# Cube_161 is empty.
#
# There are 0 points in cube_162 / 3375
# Cube_162 is empty.
#
# There are 0 points in cube_163 / 3375
# Cube_163 is empty.
#
# There are 0 points in cube_164 / 3375
# Cube_164 is empty.
#
# There are 0 points in cube_165 / 3375
# Cube_165 is empty.
#
# There are 0 points in cube_166 / 3375
# Cube_166 is empty.
#
# There are 0 points in cube_167 / 3375
# Cube_167 is empty.
#
# There are 0 points in cube_168 / 3375
# Cube_168 is empty.
#
# There are 0 points in cube_169 / 3375
# Cube_169 is empty.
#
# There are 0 points in cube_170 / 3375
# Cube_170 is empty.
#
# There are 0 points in cube_171 / 3375
# Cube_171 is empty.
#
# There are 0 points in cube_172 / 3375
# Cube_172 is empty.
#
# There are 0 points in cube_173 / 3375
# Cube_173 is empty.
#
# There are 0 points in cube_174 / 3375
# Cube_174 is empty.
#
# There are 0 points in cube_175 / 3375
# Cube_175 is empty.
#
# There are 0 points in cube_176 / 3375
# Cube_176 is empty.
#
# There are 0 points in cube_177 / 3375
# Cube_177 is empty.
#
# There are 1 points in cube_178 / 3375
# Found 1 clusters in cube_178
#
# There are 0 points in cube_179 / 3375
# Cube_179 is empty.
#
# There are 0 points in cube_180 / 3375
# Cube_180 is empty.
#
# There are 0 points in cube_181 / 3375
# Cube_181 is empty.
#
# There are 0 points in cube_182 / 3375
# Cube_182 is empty.
#
# There are 0 points in cube_183 / 3375
# Cube_183 is empty.
#
# There are 0 points in cube_184 / 3375
# Cube_184 is empty.
#
# There are 0 points in cube_185 / 3375
# Cube_185 is empty.
#
# There are 0 points in cube_186 / 3375
# Cube_186 is empty.
#
# There are 0 points in cube_187 / 3375
# Cube_187 is empty.
#
# There are 0 points in cube_188 / 3375
# Cube_188 is empty.
#
# There are 0 points in cube_189 / 3375
# Cube_189 is empty.
#
# There are 0 points in cube_190 / 3375
# Cube_190 is empty.
#
# There are 0 points in cube_191 / 3375
# Cube_191 is empty.
#
# There are 0 points in cube_192 / 3375
# Cube_192 is empty.
#
# There are 0 points in cube_193 / 3375
# Cube_193 is empty.
#
# There are 0 points in cube_194 / 3375
# Cube_194 is empty.
#
# There are 0 points in cube_195 / 3375
# Cube_195 is empty.
#
# There are 0 points in cube_196 / 3375
# Cube_196 is empty.
#
# There are 0 points in cube_197 / 3375
# Cube_197 is empty.
#
# There are 0 points in cube_198 / 3375
# Cube_198 is empty.
#
# There are 0 points in cube_199 / 3375
# Cube_199 is empty.
#
# There are 0 points in cube_200 / 3375
# Cube_200 is empty.
#
# There are 0 points in cube_201 / 3375
# Cube_201 is empty.
#
# There are 0 points in cube_202 / 3375
# Cube_202 is empty.
#
# There are 0 points in cube_203 / 3375
# Cube_203 is empty.
#
# There are 0 points in cube_204 / 3375
# Cube_204 is empty.
#
# There are 0 points in cube_205 / 3375
# Cube_205 is empty.
#
# There are 0 points in cube_206 / 3375
# Cube_206 is empty.
#
# There are 0 points in cube_207 / 3375
# Cube_207 is empty.
#
# There are 0 points in cube_208 / 3375
# Cube_208 is empty.
#
# There are 0 points in cube_209 / 3375
# Cube_209 is empty.
#
# There are 0 points in cube_210 / 3375
# Cube_210 is empty.
#
# There are 0 points in cube_211 / 3375
# Cube_211 is empty.
#
# There are 0 points in cube_212 / 3375
# Cube_212 is empty.
#
# There are 0 points in cube_213 / 3375
# Cube_213 is empty.
#
# There are 0 points in cube_214 / 3375
# Cube_214 is empty.
#
# There are 1 points in cube_215 / 3375
# Found 1 clusters in cube_215
#
# There are 0 points in cube_216 / 3375
# Cube_216 is empty.
#
# There are 0 points in cube_217 / 3375
# Cube_217 is empty.
#
# There are 0 points in cube_218 / 3375
# Cube_218 is empty.
#
# There are 0 points in cube_219 / 3375
# Cube_219 is empty.
#
# There are 0 points in cube_220 / 3375
# Cube_220 is empty.
#
# There are 0 points in cube_221 / 3375
# Cube_221 is empty.
#
# There are 0 points in cube_222 / 3375
# Cube_222 is empty.
#
# There are 0 points in cube_223 / 3375
# Cube_223 is empty.
#
# There are 0 points in cube_224 / 3375
# Cube_224 is empty.
#
# There are 0 points in cube_225 / 3375
# Cube_225 is empty.
#
# There are 0 points in cube_226 / 3375
# Cube_226 is empty.
#
# There are 0 points in cube_227 / 3375
# Cube_227 is empty.
#
# There are 0 points in cube_228 / 3375
# Cube_228 is empty.
#
# There are 0 points in cube_229 / 3375
# Cube_229 is empty.
#
# There are 0 points in cube_230 / 3375
# Cube_230 is empty.
#
# There are 0 points in cube_231 / 3375
# Cube_231 is empty.
#
# There are 0 points in cube_232 / 3375
# Cube_232 is empty.
#
# There are 0 points in cube_233 / 3375
# Cube_233 is empty.
#
# There are 0 points in cube_234 / 3375
# Cube_234 is empty.
#
# There are 0 points in cube_235 / 3375
# Cube_235 is empty.
#
# There are 0 points in cube_236 / 3375
# Cube_236 is empty.
#
# There are 0 points in cube_237 / 3375
# Cube_237 is empty.
#
# There are 0 points in cube_238 / 3375
# Cube_238 is empty.
#
# There are 0 points in cube_239 / 3375
# Cube_239 is empty.
#
# There are 0 points in cube_240 / 3375
# Cube_240 is empty.
#
# There are 0 points in cube_241 / 3375
# Cube_241 is empty.
#
# There are 0 points in cube_242 / 3375
# Cube_242 is empty.
#
# There are 0 points in cube_243 / 3375
# Cube_243 is empty.
#
# There are 0 points in cube_244 / 3375
# Cube_244 is empty.
#
# There are 0 points in cube_245 / 3375
# Cube_245 is empty.
#
# There are 0 points in cube_246 / 3375
# Cube_246 is empty.
#
# There are 0 points in cube_247 / 3375
# Cube_247 is empty.
#
# There are 0 points in cube_248 / 3375
# Cube_248 is empty.
#
# There are 0 points in cube_249 / 3375
# Cube_249 is empty.
#
# There are 0 points in cube_250 / 3375
# Cube_250 is empty.
#
# There are 0 points in cube_251 / 3375
# Cube_251 is empty.
#
# There are 0 points in cube_252 / 3375
# Cube_252 is empty.
#
# There are 0 points in cube_253 / 3375
# Cube_253 is empty.
#
# There are 0 points in cube_254 / 3375
# Cube_254 is empty.
#
# There are 0 points in cube_255 / 3375
# Cube_255 is empty.
#
# There are 0 points in cube_256 / 3375
# Cube_256 is empty.
#
# There are 0 points in cube_257 / 3375
# Cube_257 is empty.
#
# There are 0 points in cube_258 / 3375
# Cube_258 is empty.
#
# There are 0 points in cube_259 / 3375
# Cube_259 is empty.
#
# There are 0 points in cube_260 / 3375
# Cube_260 is empty.
#
# There are 0 points in cube_261 / 3375
# Cube_261 is empty.
#
# There are 0 points in cube_262 / 3375
# Cube_262 is empty.
#
# There are 0 points in cube_263 / 3375
# Cube_263 is empty.
#
# There are 0 points in cube_264 / 3375
# Cube_264 is empty.
#
# There are 0 points in cube_265 / 3375
# Cube_265 is empty.
#
# There are 0 points in cube_266 / 3375
# Cube_266 is empty.
#
# There are 0 points in cube_267 / 3375
# Cube_267 is empty.
#
# There are 0 points in cube_268 / 3375
# Cube_268 is empty.
#
# There are 0 points in cube_269 / 3375
# Cube_269 is empty.
#
# There are 0 points in cube_270 / 3375
# Cube_270 is empty.
#
# There are 0 points in cube_271 / 3375
# Cube_271 is empty.
#
# There are 0 points in cube_272 / 3375
# Cube_272 is empty.
#
# There are 0 points in cube_273 / 3375
# Cube_273 is empty.
#
# There are 0 points in cube_274 / 3375
# Cube_274 is empty.
#
# There are 0 points in cube_275 / 3375
# Cube_275 is empty.
#
# There are 0 points in cube_276 / 3375
# Cube_276 is empty.
#
# There are 0 points in cube_277 / 3375
# Cube_277 is empty.
#
# There are 0 points in cube_278 / 3375
# Cube_278 is empty.
#
# There are 0 points in cube_279 / 3375
# Cube_279 is empty.
#
# There are 0 points in cube_280 / 3375
# Cube_280 is empty.
#
# There are 0 points in cube_281 / 3375
# Cube_281 is empty.
#
# There are 0 points in cube_282 / 3375
# Cube_282 is empty.
#
# There are 0 points in cube_283 / 3375
# Cube_283 is empty.
#
# There are 0 points in cube_284 / 3375
# Cube_284 is empty.
# There are 0 points in cube_285 / 3375
# Cube_285 is empty.
#
# There are 0 points in cube_286 / 3375
# Cube_286 is empty.
#
# There are 0 points in cube_287 / 3375
# Cube_287 is empty.
#
# There are 0 points in cube_288 / 3375
# Cube_288 is empty.
#
# There are 0 points in cube_289 / 3375
# Cube_289 is empty.
#
# There are 0 points in cube_290 / 3375
# Cube_290 is empty.
#
# There are 0 points in cube_291 / 3375
# Cube_291 is empty.
#
# There are 0 points in cube_292 / 3375
# Cube_292 is empty.
#
# There are 0 points in cube_293 / 3375
# Cube_293 is empty.
#
# There are 0 points in cube_294 / 3375
# Cube_294 is empty.
#
# There are 0 points in cube_295 / 3375
# Cube_295 is empty.
#
# There are 0 points in cube_296 / 3375
# Cube_296 is empty.
#
# There are 0 points in cube_297 / 3375
# Cube_297 is empty.
#
# There are 0 points in cube_298 / 3375
# Cube_298 is empty.
#
# There are 0 points in cube_299 / 3375
# Cube_299 is empty.
#
# There are 2 points in cube_300 / 3375
# Found 1 clusters in cube_300
#
# There are 52 points in cube_301 / 3375
# Found 1 clusters in cube_301
#
# There are 370 points in cube_302 / 3375
# Found 2 clusters in cube_302
#
# There are 1050 points in cube_303 / 3375
# Found 3 clusters in cube_303
#
# There are 1721 points in cube_304 / 3375
# Found 3 clusters in cube_304
#
# There are 2943 points in cube_305 / 3375
# Found 3 clusters in cube_305
#
# There are 4261 points in cube_306 / 3375
# Found 4 clusters in cube_306
#
# There are 5548 points in cube_307 / 3375
# Found 4 clusters in cube_307
#
# There are 8146 points in cube_308 / 3375
# Found 4 clusters in cube_308
#
# There are 13995 points in cube_309 / 3375
# Found 4 clusters in cube_309
#
# There are 35638 points in cube_310 / 3375
# Found 5 clusters in cube_310
#
# There are 55189 points in cube_311 / 3375
# Found 5 clusters in cube_311
#
# There are 0 points in cube_312 / 3375
# Cube_312 is empty.
#
# There are 0 points in cube_313 / 3375
# Cube_313 is empty.
#
# There are 0 points in cube_314 / 3375
# Cube_314 is empty.
#
# There are 0 points in cube_315 / 3375
# Cube_315 is empty.
#
# There are 24 points in cube_316 / 3375
# Found 1 clusters in cube_316
#
# There are 78 points in cube_317 / 3375
# Found 2 clusters in cube_317
#
# There are 111 points in cube_318 / 3375
# Found 2 clusters in cube_318
#
# There are 87 points in cube_319 / 3375
# Found 2 clusters in cube_319
#
# There are 63 points in cube_320 / 3375
# Found 2 clusters in cube_320
#
# There are 58 points in cube_321 / 3375
# Found 2 clusters in cube_321
#
# There are 49 points in cube_322 / 3375
# Found 1 clusters in cube_322
#
# There are 50 points in cube_323 / 3375
# Found 1 clusters in cube_323
#
# There are 32 points in cube_324 / 3375
# Found 1 clusters in cube_324
#
# There are 41 points in cube_325 / 3375
# Found 1 clusters in cube_325
#
# There are 54 points in cube_326 / 3375
# Found 2 clusters in cube_326
#
# There are 273 points in cube_327 / 3375
# Found 2 clusters in cube_327
#
# There are 1631 points in cube_328 / 3375
# Found 3 clusters in cube_328
#
# There are 62 points in cube_329 / 3375
# Found 2 clusters in cube_329
#
# There are 0 points in cube_330 / 3375
# Cube_330 is empty.
#
# There are 0 points in cube_331 / 3375
# Cube_331 is empty.
#
# There are 0 points in cube_332 / 3375
# Cube_332 is empty.
#
# There are 0 points in cube_333 / 3375
# Cube_333 is empty.
#
# There are 10 points in cube_334 / 3375
# Found 1 clusters in cube_334
#
# There are 117 points in cube_335 / 3375
# Found 2 clusters in cube_335
#
# There are 1740 points in cube_336 / 3375
# Found 3 clusters in cube_336
#
# There are 1334 points in cube_337 / 3375
# Found 3 clusters in cube_337
#
# There are 1316 points in cube_338 / 3375
# Found 3 clusters in cube_338
#
# There are 4422 points in cube_339 / 3375
# Found 4 clusters in cube_339
#
# There are 7716 points in cube_340 / 3375
# Found 4 clusters in cube_340
#
# There are 13671 points in cube_341 / 3375
# Found 4 clusters in cube_341
#
# There are 22871 points in cube_342 / 3375
# Found 5 clusters in cube_342
#
# There are 119187 points in cube_343 / 3375
# Found 5 clusters in cube_343
#
# There are 53006 points in cube_344 / 3375
# Found 5 clusters in cube_344
#
# There are 0 points in cube_345 / 3375
# Cube_345 is empty.
#
# There are 1 points in cube_346 / 3375
# Found 1 clusters in cube_346
#
# There are 14 points in cube_347 / 3375
# Found 1 clusters in cube_347
#
# There are 9 points in cube_348 / 3375
# Found 1 clusters in cube_348
#
# There are 0 points in cube_349 / 3375
# Cube_349 is empty.
#
# There are 0 points in cube_350 / 3375
# Cube_350 is empty.
#
# There are 0 points in cube_351 / 3375
# Cube_351 is empty.
#
# There are 0 points in cube_352 / 3375
# Cube_352 is empty.
#
# There are 0 points in cube_353 / 3375
# Cube_353 is empty.
#
# There are 3 points in cube_354 / 3375
# Found 1 clusters in cube_354
#
# There are 5 points in cube_355 / 3375
# Found 1 clusters in cube_355
#
# There are 4 points in cube_356 / 3375
# Found 1 clusters in cube_356
#
# There are 45 points in cube_357 / 3375
# Found 1 clusters in cube_357
#
# There are 811 points in cube_358 / 3375
# Found 3 clusters in cube_358
#
# There are 21 points in cube_359 / 3375
# Found 1 clusters in cube_359
#
# There are 0 points in cube_360 / 3375
# Cube_360 is empty.
#
# There are 2 points in cube_361 / 3375
# Found 1 clusters in cube_361
#
# There are 7 points in cube_362 / 3375
# Found 1 clusters in cube_362
#
# There are 0 points in cube_363 / 3375
# Cube_363 is empty.
#
# There are 0 points in cube_364 / 3375
# Cube_364 is empty.
#
# There are 0 points in cube_365 / 3375
# Cube_365 is empty.
#
# There are 0 points in cube_366 / 3375
# Cube_366 is empty.
#
# There are 0 points in cube_367 / 3375
# Cube_367 is empty.
#
# There are 0 points in cube_368 / 3375
# Cube_368 is empty.
#
# There are 1 points in cube_369 / 3375
# Found 1 clusters in cube_369
#
# There are 1 points in cube_370 / 3375
# Found 1 clusters in cube_370
#
# There are 0 points in cube_371 / 3375
# Cube_371 is empty.
#
# There are 2 points in cube_372 / 3375
# Found 1 clusters in cube_372
#
# There are 45 points in cube_373 / 3375
# Found 1 clusters in cube_373
#
# There are 0 points in cube_374 / 3375
# Cube_374 is empty.
#
# There are 0 points in cube_375 / 3375
# Cube_375 is empty.
#
# There are 0 points in cube_376 / 3375
# Cube_376 is empty.
#
# There are 0 points in cube_377 / 3375
# Cube_377 is empty.
#
# There are 0 points in cube_378 / 3375
# Cube_378 is empty.
#
# There are 0 points in cube_379 / 3375
# Cube_379 is empty.
#
# There are 0 points in cube_380 / 3375
# Cube_380 is empty.
#
# There are 0 points in cube_381 / 3375
# Cube_381 is empty.
#
# There are 0 points in cube_382 / 3375
# Cube_382 is empty.
#
# There are 0 points in cube_383 / 3375
# Cube_383 is empty.
#
# There are 0 points in cube_384 / 3375
# Cube_384 is empty.
#
# There are 0 points in cube_385 / 3375
# Cube_385 is empty.
#
# There are 0 points in cube_386 / 3375
# Cube_386 is empty.
#
# There are 0 points in cube_387 / 3375
# Cube_387 is empty.
#
# There are 0 points in cube_388 / 3375
# Cube_388 is empty.
#
# There are 0 points in cube_389 / 3375
# Cube_389 is empty.
#
# There are 0 points in cube_390 / 3375
# Cube_390 is empty.
#
# There are 0 points in cube_391 / 3375
# Cube_391 is empty.
#
# There are 0 points in cube_392 / 3375
# Cube_392 is empty.
#
# There are 0 points in cube_393 / 3375
# Cube_393 is empty.
#
# There are 0 points in cube_394 / 3375
# Cube_394 is empty.
#
# There are 0 points in cube_395 / 3375
# Cube_395 is empty.
#
# There are 0 points in cube_396 / 3375
# Cube_396 is empty.
#
# There are 0 points in cube_397 / 3375
# Cube_397 is empty.
#
# There are 0 points in cube_398 / 3375
# Cube_398 is empty.
#
# There are 0 points in cube_399 / 3375
# Cube_399 is empty.
#
# There are 0 points in cube_400 / 3375
# Cube_400 is empty.
#
# There are 0 points in cube_401 / 3375
# Cube_401 is empty.
#
# There are 0 points in cube_402 / 3375
# Cube_402 is empty.
#
# There are 0 points in cube_403 / 3375
# Cube_403 is empty.
#
# There are 0 points in cube_404 / 3375
# Cube_404 is empty.
#
# There are 0 points in cube_405 / 3375
# Cube_405 is empty.
#
# There are 0 points in cube_406 / 3375
# Cube_406 is empty.
#
# There are 0 points in cube_407 / 3375
# Cube_407 is empty.
#
# There are 0 points in cube_408 / 3375
# Cube_408 is empty.
#
# There are 0 points in cube_409 / 3375
# Cube_409 is empty.
#
# There are 0 points in cube_410 / 3375
# Cube_410 is empty.
#
# There are 0 points in cube_411 / 3375
# Cube_411 is empty.
#
# There are 0 points in cube_412 / 3375
# Cube_412 is empty.
#
# There are 0 points in cube_413 / 3375
# Cube_413 is empty.
#
# There are 0 points in cube_414 / 3375
# Cube_414 is empty.
#
# There are 0 points in cube_415 / 3375
# Cube_415 is empty.
#
# There are 0 points in cube_416 / 3375
# Cube_416 is empty.
# There are 0 points in cube_417 / 3375
# Cube_417 is empty.
#
# There are 0 points in cube_418 / 3375
# Cube_418 is empty.
#
# There are 0 points in cube_419 / 3375
# Cube_419 is empty.
#
# There are 0 points in cube_420 / 3375
# Cube_420 is empty.
#
# There are 0 points in cube_421 / 3375
# Cube_421 is empty.
#
# There are 0 points in cube_422 / 3375
# Cube_422 is empty.
#
# There are 0 points in cube_423 / 3375
# Cube_423 is empty.
#
# There are 0 points in cube_424 / 3375
# Cube_424 is empty.
#
# There are 0 points in cube_425 / 3375
# Cube_425 is empty.
#
# There are 0 points in cube_426 / 3375
# Cube_426 is empty.
#
# There are 0 points in cube_427 / 3375
# Cube_427 is empty.
#
# There are 0 points in cube_428 / 3375
# Cube_428 is empty.
#
# There are 0 points in cube_429 / 3375
# Cube_429 is empty.
#
# There are 0 points in cube_430 / 3375
# Cube_430 is empty.
#
# There are 0 points in cube_431 / 3375
# Cube_431 is empty.
#
# There are 0 points in cube_432 / 3375
# Cube_432 is empty.
#
# There are 0 points in cube_433 / 3375
# Cube_433 is empty.
#
# There are 0 points in cube_434 / 3375
# Cube_434 is empty.
#
# There are 0 points in cube_435 / 3375
# Cube_435 is empty.
#
# There are 0 points in cube_436 / 3375
# Cube_436 is empty.
#
# There are 0 points in cube_437 / 3375
# Cube_437 is empty.
#
# There are 0 points in cube_438 / 3375
# Cube_438 is empty.
#
# There are 0 points in cube_439 / 3375
# Cube_439 is empty.
#
# There are 0 points in cube_440 / 3375
# Cube_440 is empty.
#
# There are 0 points in cube_441 / 3375
# Cube_441 is empty.
#
# There are 0 points in cube_442 / 3375
# Cube_442 is empty.
#
# There are 0 points in cube_443 / 3375
# Cube_443 is empty.
#
# There are 0 points in cube_444 / 3375
# Cube_444 is empty.
#
# There are 0 points in cube_445 / 3375
# Cube_445 is empty.
#
# There are 0 points in cube_446 / 3375
# Cube_446 is empty.
#
# There are 0 points in cube_447 / 3375
# Cube_447 is empty.
#
# There are 0 points in cube_448 / 3375
# Cube_448 is empty.
#
# There are 0 points in cube_449 / 3375
# Cube_449 is empty.
#
# There are 0 points in cube_450 / 3375
# Cube_450 is empty.
#
# There are 0 points in cube_451 / 3375
# Cube_451 is empty.
#
# There are 0 points in cube_452 / 3375
# Cube_452 is empty.
#
# There are 0 points in cube_453 / 3375
# Cube_453 is empty.
#
# There are 0 points in cube_454 / 3375
# Cube_454 is empty.
#
# There are 0 points in cube_455 / 3375
# Cube_455 is empty.
#
# There are 0 points in cube_456 / 3375
# Cube_456 is empty.
#
# There are 0 points in cube_457 / 3375
# Cube_457 is empty.
#
# There are 0 points in cube_458 / 3375
# Cube_458 is empty.
#
# There are 0 points in cube_459 / 3375
# Cube_459 is empty.
#
# There are 0 points in cube_460 / 3375
# Cube_460 is empty.
#
# There are 0 points in cube_461 / 3375
# Cube_461 is empty.
#
# There are 0 points in cube_462 / 3375
# Cube_462 is empty.
#
# There are 0 points in cube_463 / 3375
# Cube_463 is empty.
#
# There are 0 points in cube_464 / 3375
# Cube_464 is empty.
#
# There are 0 points in cube_465 / 3375
# Cube_465 is empty.
#
# There are 0 points in cube_466 / 3375
# Cube_466 is empty.
#
# There are 0 points in cube_467 / 3375
# Cube_467 is empty.
#
# There are 0 points in cube_468 / 3375
# Cube_468 is empty.
#
# There are 0 points in cube_469 / 3375
# Cube_469 is empty.
#
# There are 0 points in cube_470 / 3375
# Cube_470 is empty.
#
# There are 0 points in cube_471 / 3375
# Cube_471 is empty.
#
# There are 0 points in cube_472 / 3375
# Cube_472 is empty.
#
# There are 0 points in cube_473 / 3375
# Cube_473 is empty.
#
# There are 0 points in cube_474 / 3375
# Cube_474 is empty.
#
# There are 0 points in cube_475 / 3375
# Cube_475 is empty.
#
# There are 0 points in cube_476 / 3375
# Cube_476 is empty.
#
# There are 0 points in cube_477 / 3375
# Cube_477 is empty.
#
# There are 0 points in cube_478 / 3375
# Cube_478 is empty.
#
# There are 0 points in cube_479 / 3375
# Cube_479 is empty.
#
# There are 0 points in cube_480 / 3375
# Cube_480 is empty.
#
# There are 0 points in cube_481 / 3375
# Cube_481 is empty.
#
# There are 0 points in cube_482 / 3375
# Cube_482 is empty.
#
# There are 0 points in cube_483 / 3375
# Cube_483 is empty.
#
# There are 0 points in cube_484 / 3375
# Cube_484 is empty.
#
# There are 0 points in cube_485 / 3375
# Cube_485 is empty.
#
# There are 0 points in cube_486 / 3375
# Cube_486 is empty.
#
# There are 0 points in cube_487 / 3375
# Cube_487 is empty.
#
# There are 0 points in cube_488 / 3375
# Cube_488 is empty.
#
# There are 0 points in cube_489 / 3375
# Cube_489 is empty.
#
# There are 0 points in cube_490 / 3375
# Cube_490 is empty.
#
# There are 0 points in cube_491 / 3375
# Cube_491 is empty.
#
# There are 0 points in cube_492 / 3375
# Cube_492 is empty.
#
# There are 0 points in cube_493 / 3375
# Cube_493 is empty.
#
# There are 0 points in cube_494 / 3375
# Cube_494 is empty.
#
# There are 0 points in cube_495 / 3375
# Cube_495 is empty.
#
# There are 0 points in cube_496 / 3375
# Cube_496 is empty.
#
# There are 0 points in cube_497 / 3375
# Cube_497 is empty.
#
# There are 0 points in cube_498 / 3375
# Cube_498 is empty.
#
# There are 0 points in cube_499 / 3375
# Cube_499 is empty.
#
# There are 0 points in cube_500 / 3375
# Cube_500 is empty.
#
# There are 0 points in cube_501 / 3375
# Cube_501 is empty.
#
# There are 0 points in cube_502 / 3375
# Cube_502 is empty.
#
# There are 0 points in cube_503 / 3375
# Cube_503 is empty.
#
# There are 0 points in cube_504 / 3375
# Cube_504 is empty.
#
# There are 0 points in cube_505 / 3375
# Cube_505 is empty.
#
# There are 0 points in cube_506 / 3375
# Cube_506 is empty.
#
# There are 0 points in cube_507 / 3375
# Cube_507 is empty.
#
# There are 0 points in cube_508 / 3375
# Cube_508 is empty.
#
# There are 0 points in cube_509 / 3375
# Cube_509 is empty.
#
# There are 0 points in cube_510 / 3375
# Cube_510 is empty.
#
# There are 0 points in cube_511 / 3375
# Cube_511 is empty.
#
# There are 0 points in cube_512 / 3375
# Cube_512 is empty.
#
# There are 0 points in cube_513 / 3375
# Cube_513 is empty.
#
# There are 0 points in cube_514 / 3375
# Cube_514 is empty.
#
# There are 0 points in cube_515 / 3375
# Cube_515 is empty.
#
# There are 0 points in cube_516 / 3375
# Cube_516 is empty.
#
# There are 0 points in cube_517 / 3375
# Cube_517 is empty.
#
# There are 0 points in cube_518 / 3375
# Cube_518 is empty.
#
# There are 0 points in cube_519 / 3375
# Cube_519 is empty.
#
# There are 0 points in cube_520 / 3375
# Cube_520 is empty.
#
# There are 0 points in cube_521 / 3375
# Cube_521 is empty.
#
# There are 0 points in cube_522 / 3375
# Cube_522 is empty.
#
# There are 0 points in cube_523 / 3375
# Cube_523 is empty.
#
# There are 0 points in cube_524 / 3375
# Cube_524 is empty.
#
# There are 1 points in cube_525 / 3375
# Found 1 clusters in cube_525
#
# There are 3 points in cube_526 / 3375
# Found 1 clusters in cube_526
#
# There are 3 points in cube_527 / 3375
# Found 1 clusters in cube_527
#
# There are 1 points in cube_528 / 3375
# Found 1 clusters in cube_528
#
# There are 1 points in cube_529 / 3375
# Found 1 clusters in cube_529
#
# There are 0 points in cube_530 / 3375
# Cube_530 is empty.
#
# There are 1 points in cube_531 / 3375
# Found 1 clusters in cube_531
#
# There are 2 points in cube_532 / 3375
# Found 1 clusters in cube_532
#
# There are 2 points in cube_533 / 3375
# Found 1 clusters in cube_533
#
# There are 1 points in cube_534 / 3375
# Found 1 clusters in cube_534
#
# There are 0 points in cube_535 / 3375
# Cube_535 is empty.
#
# There are 0 points in cube_536 / 3375
# Cube_536 is empty.
#
# There are 17 points in cube_537 / 3375
# Found 1 clusters in cube_537
#
# There are 288 points in cube_538 / 3375
# Found 2 clusters in cube_538
#
# There are 0 points in cube_539 / 3375
# Cube_539 is empty.
#
# There are 2 points in cube_540 / 3375
# Found 1 clusters in cube_540
#
# There are 2 points in cube_541 / 3375
# Found 1 clusters in cube_541
#
# There are 7 points in cube_542 / 3375
# Found 1 clusters in cube_542
#
# There are 7 points in cube_543 / 3375
# Found 1 clusters in cube_543
#
# There are 2 points in cube_544 / 3375
# Found 1 clusters in cube_544
#
# There are 0 points in cube_545 / 3375
# Cube_545 is empty.
#
# There are 0 points in cube_546 / 3375
# Cube_546 is empty.
#
# There are 3 points in cube_547 / 3375
# Found 1 clusters in cube_547
#
# There are 5 points in cube_548 / 3375
# Found 1 clusters in cube_548
#
# There are 5 points in cube_549 / 3375
# Found 1 clusters in cube_549
#
# There are 33 points in cube_550 / 3375
# Found 1 clusters in cube_550
#
# There are 48 points in cube_551 / 3375
# Found 1 clusters in cube_551
#
# There are 197 points in cube_552 / 3375
# Found 2 clusters in cube_552
#
# There are 1557 points in cube_553 / 3375
# Found 3 clusters in cube_553
#
# There are 22 points in cube_554 / 3375
# Found 1 clusters in cube_554
#
# There are 0 points in cube_555 / 3375
# Cube_555 is empty.
#
# There are 233 points in cube_556 / 3375
# Found 2 clusters in cube_556
#
# There are 1031 points in cube_557 / 3375
# Found 3 clusters in cube_557
#
# There are 829 points in cube_558 / 3375
# Found 3 clusters in cube_558
#
# There are 333 points in cube_559 / 3375
# Found 2 clusters in cube_559
#
# There are 582 points in cube_560 / 3375
# Found 3 clusters in cube_560
#
# There are 1890 points in cube_561 / 3375
# Found 3 clusters in cube_561
#
# There are 4877 points in cube_562 / 3375
# Found 4 clusters in cube_562
#
# There are 9119 points in cube_563 / 3375
# Found 4 clusters in cube_563
#
# There are 16810 points in cube_564 / 3375
# Found 4 clusters in cube_564
#
# There are 32494 points in cube_565 / 3375
# Found 5 clusters in cube_565
#
# There are 30840 points in cube_566 / 3375
# Found 5 clusters in cube_566
#
# There are 9167 points in cube_567 / 3375
# Found 4 clusters in cube_567
#
# There are 195 points in cube_568 / 3375
# Found 2 clusters in cube_568
#
# There are 4 points in cube_569 / 3375
# Found 1 clusters in cube_569
#
# There are 0 points in cube_570 / 3375
# Cube_570 is empty.
#
# There are 0 points in cube_571 / 3375
# Cube_571 is empty.
#
# There are 0 points in cube_572 / 3375
# Cube_572 is empty.
#
# There are 0 points in cube_573 / 3375
# Cube_573 is empty.
#
# There are 2 points in cube_574 / 3375
# Found 1 clusters in cube_574
#
# There are 158 points in cube_575 / 3375
# Found 2 clusters in cube_575
#
# There are 1377 points in cube_576 / 3375
# Found 3 clusters in cube_576
#
# There are 3942 points in cube_577 / 3375
# Found 4 clusters in cube_577
#
# There are 7637 points in cube_578 / 3375
# Found 4 clusters in cube_578
#
# There are 6751 points in cube_579 / 3375
# Found 4 clusters in cube_579
#
# There are 5083 points in cube_580 / 3375
# Found 4 clusters in cube_580
#
# There are 2114 points in cube_581 / 3375
# Found 3 clusters in cube_581
#
# There are 176 points in cube_582 / 3375
# Found 2 clusters in cube_582
#
# There are 12 points in cube_583 / 3375
# Found 1 clusters in cube_583
#
# There are 0 points in cube_584 / 3375
# Cube_584 is empty.
#
# There are 0 points in cube_585 / 3375
# Cube_585 is empty.
#
# There are 0 points in cube_586 / 3375
# Cube_586 is empty.
#
# There are 0 points in cube_587 / 3375
# Cube_587 is empty.
#
# There are 0 points in cube_588 / 3375
# Cube_588 is empty.
#
# There are 0 points in cube_589 / 3375
# Cube_589 is empty.
#
# There are 0 points in cube_590 / 3375
# Cube_590 is empty.
#
# There are 0 points in cube_591 / 3375
# Cube_591 is empty.
#
# There are 0 points in cube_592 / 3375
# Cube_592 is empty.
#
# There are 0 points in cube_593 / 3375
# Cube_593 is empty.
#
# There are 113 points in cube_594 / 3375
# Found 2 clusters in cube_594
#
# There are 465 points in cube_595 / 3375
# Found 3 clusters in cube_595
#
# There are 250 points in cube_596 / 3375
# Found 2 clusters in cube_596
#
# There are 137 points in cube_597 / 3375
# Found 2 clusters in cube_597
#
# There are 2 points in cube_598 / 3375
# Found 1 clusters in cube_598
#
# There are 0 points in cube_599 / 3375
# Cube_599 is empty.
#
# There are 0 points in cube_600 / 3375
# Cube_600 is empty.
#
# There are 0 points in cube_601 / 3375
# Cube_601 is empty.
#
# There are 0 points in cube_602 / 3375
# Cube_602 is empty.
#
# There are 0 points in cube_603 / 3375
# Cube_603 is empty.
#
# There are 0 points in cube_604 / 3375
# Cube_604 is empty.
#
# There are 0 points in cube_605 / 3375
# Cube_605 is empty.
#
# There are 0 points in cube_606 / 3375
# Cube_606 is empty.
#
# There are 0 points in cube_607 / 3375
# Cube_607 is empty.
#
# There are 0 points in cube_608 / 3375
# Cube_608 is empty.
#
# There are 14 points in cube_609 / 3375
# Found 1 clusters in cube_609
#
# There are 0 points in cube_610 / 3375
# Cube_610 is empty.
#
# There are 0 points in cube_611 / 3375
# Cube_611 is empty.
#
# There are 0 points in cube_612 / 3375
# Cube_612 is empty.
#
# There are 0 points in cube_613 / 3375
# Cube_613 is empty.
#
# There are 0 points in cube_614 / 3375
# Cube_614 is empty.
#
# There are 0 points in cube_615 / 3375
# Cube_615 is empty.
#
# There are 0 points in cube_616 / 3375
# Cube_616 is empty.
#
# There are 0 points in cube_617 / 3375
# Cube_617 is empty.
#
# There are 0 points in cube_618 / 3375
# Cube_618 is empty.
#
# There are 0 points in cube_619 / 3375
# Cube_619 is empty.
#
# There are 0 points in cube_620 / 3375
# Cube_620 is empty.
#
# There are 0 points in cube_621 / 3375
# Cube_621 is empty.
#
# There are 0 points in cube_622 / 3375
# Cube_622 is empty.
#
# There are 0 points in cube_623 / 3375
# Cube_623 is empty.
#
# There are 0 points in cube_624 / 3375
# Cube_624 is empty.
#
# There are 0 points in cube_625 / 3375
# Cube_625 is empty.
#
# There are 0 points in cube_626 / 3375
# Cube_626 is empty.
#
# There are 0 points in cube_627 / 3375
# Cube_627 is empty.
#
# There are 0 points in cube_628 / 3375
# Cube_628 is empty.
#
# There are 0 points in cube_629 / 3375
# Cube_629 is empty.
#
# There are 0 points in cube_630 / 3375
# Cube_630 is empty.
#
# There are 0 points in cube_631 / 3375
# Cube_631 is empty.
#
# There are 0 points in cube_632 / 3375
# Cube_632 is empty.
#
# There are 0 points in cube_633 / 3375
# Cube_633 is empty.
#
# There are 0 points in cube_634 / 3375
# Cube_634 is empty.
#
# There are 0 points in cube_635 / 3375
# Cube_635 is empty.
#
# There are 0 points in cube_636 / 3375
# Cube_636 is empty.
#
# There are 0 points in cube_637 / 3375
# Cube_637 is empty.
#
# There are 0 points in cube_638 / 3375
# Cube_638 is empty.
#
# There are 0 points in cube_639 / 3375
# Cube_639 is empty.
#
# There are 0 points in cube_640 / 3375
# Cube_640 is empty.
#
# There are 0 points in cube_641 / 3375
# Cube_641 is empty.
#
# There are 0 points in cube_642 / 3375
# Cube_642 is empty.
#
# There are 0 points in cube_643 / 3375
# Cube_643 is empty.
#
# There are 0 points in cube_644 / 3375
# Cube_644 is empty.
#
# There are 0 points in cube_645 / 3375
# Cube_645 is empty.
#
# There are 0 points in cube_646 / 3375
# Cube_646 is empty.
#
# There are 0 points in cube_647 / 3375
# Cube_647 is empty.
#
# There are 0 points in cube_648 / 3375
# Cube_648 is empty.
#
# There are 0 points in cube_649 / 3375
# Cube_649 is empty.
#
# There are 0 points in cube_650 / 3375
# Cube_650 is empty.
#
# There are 0 points in cube_651 / 3375
# Cube_651 is empty.
#
# There are 0 points in cube_652 / 3375
# Cube_652 is empty.
#
# There are 0 points in cube_653 / 3375
# Cube_653 is empty.
#
# There are 0 points in cube_654 / 3375
# Cube_654 is empty.
#
# There are 0 points in cube_655 / 3375
# Cube_655 is empty.
#
# There are 0 points in cube_656 / 3375
# Cube_656 is empty.
#
# There are 0 points in cube_657 / 3375
# Cube_657 is empty.
#
# There are 0 points in cube_658 / 3375
# Cube_658 is empty.
#
# There are 0 points in cube_659 / 3375
# Cube_659 is empty.
#
# There are 0 points in cube_660 / 3375
# Cube_660 is empty.
#
# There are 0 points in cube_661 / 3375
# Cube_661 is empty.
#
# There are 0 points in cube_662 / 3375
# Cube_662 is empty.
#
# There are 0 points in cube_663 / 3375
# Cube_663 is empty.
#
# There are 0 points in cube_664 / 3375
# Cube_664 is empty.
#
# There are 0 points in cube_665 / 3375
# Cube_665 is empty.
#
# There are 1 points in cube_666 / 3375
# Found 1 clusters in cube_666
#
# There are 1 points in cube_667 / 3375
# Found 1 clusters in cube_667
#
# There are 0 points in cube_668 / 3375
# Cube_668 is empty.
#
# There are 0 points in cube_669 / 3375
# Cube_669 is empty.
#
# There are 0 points in cube_670 / 3375
# Cube_670 is empty.
#
# There are 0 points in cube_671 / 3375
# Cube_671 is empty.
#
# There are 0 points in cube_672 / 3375
# Cube_672 is empty.
#
# There are 0 points in cube_673 / 3375
# Cube_673 is empty.
#
# There are 0 points in cube_674 / 3375
# Cube_674 is empty.
#
# There are 0 points in cube_675 / 3375
# Cube_675 is empty.
#
# There are 0 points in cube_676 / 3375
# Cube_676 is empty.
#
# There are 0 points in cube_677 / 3375
# Cube_677 is empty.
#
# There are 0 points in cube_678 / 3375
# Cube_678 is empty.
#
# There are 0 points in cube_679 / 3375
# Cube_679 is empty.
#
# There are 0 points in cube_680 / 3375
# Cube_680 is empty.
#
# There are 0 points in cube_681 / 3375
# Cube_681 is empty.
#
# There are 0 points in cube_682 / 3375
# Cube_682 is empty.
#
# There are 0 points in cube_683 / 3375
# Cube_683 is empty.
#
# There are 0 points in cube_684 / 3375
# Cube_684 is empty.
#
# There are 0 points in cube_685 / 3375
# Cube_685 is empty.
#
# There are 0 points in cube_686 / 3375
# Cube_686 is empty.
#
# There are 0 points in cube_687 / 3375
# Cube_687 is empty.
#
# There are 0 points in cube_688 / 3375
# Cube_688 is empty.
#
# There are 0 points in cube_689 / 3375
# Cube_689 is empty.
#
# There are 0 points in cube_690 / 3375
# Cube_690 is empty.
#
# There are 0 points in cube_691 / 3375
# Cube_691 is empty.
#
# There are 0 points in cube_692 / 3375
# Cube_692 is empty.
#
# There are 0 points in cube_693 / 3375
# Cube_693 is empty.
#
# There are 0 points in cube_694 / 3375
# Cube_694 is empty.
# There are 0 points in cube_695 / 3375
# Cube_695 is empty.
#
# There are 0 points in cube_696 / 3375
# Cube_696 is empty.
#
# There are 0 points in cube_697 / 3375
# Cube_697 is empty.
#
# There are 0 points in cube_698 / 3375
# Cube_698 is empty.
#
# There are 0 points in cube_699 / 3375
# Cube_699 is empty.
#
# There are 0 points in cube_700 / 3375
# Cube_700 is empty.
#
# There are 0 points in cube_701 / 3375
# Cube_701 is empty.
#
# There are 0 points in cube_702 / 3375
# Cube_702 is empty.
#
# There are 0 points in cube_703 / 3375
# Cube_703 is empty.
#
# There are 0 points in cube_704 / 3375
# Cube_704 is empty.
#
# There are 0 points in cube_705 / 3375
# Cube_705 is empty.
#
# There are 0 points in cube_706 / 3375
# Cube_706 is empty.
#
# There are 0 points in cube_707 / 3375
# Cube_707 is empty.
#
# There are 0 points in cube_708 / 3375
# Cube_708 is empty.
#
# There are 0 points in cube_709 / 3375
# Cube_709 is empty.
#
# There are 0 points in cube_710 / 3375
# Cube_710 is empty.
#
# There are 0 points in cube_711 / 3375
# Cube_711 is empty.
#
# There are 0 points in cube_712 / 3375
# Cube_712 is empty.
#
# There are 0 points in cube_713 / 3375
# Cube_713 is empty.
#
# There are 0 points in cube_714 / 3375
# Cube_714 is empty.
#
# There are 0 points in cube_715 / 3375
# Cube_715 is empty.
#
# There are 0 points in cube_716 / 3375
# Cube_716 is empty.
#
# There are 0 points in cube_717 / 3375
# Cube_717 is empty.
#
# There are 0 points in cube_718 / 3375
# Cube_718 is empty.
#
# There are 0 points in cube_719 / 3375
# Cube_719 is empty.
#
# There are 0 points in cube_720 / 3375
# Cube_720 is empty.
#
# There are 0 points in cube_721 / 3375
# Cube_721 is empty.
#
# There are 0 points in cube_722 / 3375
# Cube_722 is empty.
#
# There are 0 points in cube_723 / 3375
# Cube_723 is empty.
#
# There are 0 points in cube_724 / 3375
# Cube_724 is empty.
#
# There are 0 points in cube_725 / 3375
# Cube_725 is empty.
#
# There are 0 points in cube_726 / 3375
# Cube_726 is empty.
#
# There are 0 points in cube_727 / 3375
# Cube_727 is empty.
#
# There are 0 points in cube_728 / 3375
# Cube_728 is empty.
#
# There are 0 points in cube_729 / 3375
# Cube_729 is empty.
#
# There are 0 points in cube_730 / 3375
# Cube_730 is empty.
#
# There are 0 points in cube_731 / 3375
# Cube_731 is empty.
#
# There are 0 points in cube_732 / 3375
# Cube_732 is empty.
#
# There are 0 points in cube_733 / 3375
# Cube_733 is empty.
#
# There are 0 points in cube_734 / 3375
# Cube_734 is empty.
#
# There are 0 points in cube_735 / 3375
# Cube_735 is empty.
#
# There are 0 points in cube_736 / 3375
# Cube_736 is empty.
#
# There are 0 points in cube_737 / 3375
# Cube_737 is empty.
#
# There are 0 points in cube_738 / 3375
# Cube_738 is empty.
#
# There are 0 points in cube_739 / 3375
# Cube_739 is empty.
#
# There are 0 points in cube_740 / 3375
# Cube_740 is empty.
#
# There are 0 points in cube_741 / 3375
# Cube_741 is empty.
#
# There are 0 points in cube_742 / 3375
# Cube_742 is empty.
#
# There are 0 points in cube_743 / 3375
# Cube_743 is empty.
#
# There are 0 points in cube_744 / 3375
# Cube_744 is empty.
#
# There are 0 points in cube_745 / 3375
# Cube_745 is empty.
#
# There are 0 points in cube_746 / 3375
# Cube_746 is empty.
#
# There are 0 points in cube_747 / 3375
# Cube_747 is empty.
#
# There are 0 points in cube_748 / 3375
# Cube_748 is empty.
#
# There are 0 points in cube_749 / 3375
# Cube_749 is empty.
#
# There are 0 points in cube_750 / 3375
# Cube_750 is empty.
#
# There are 0 points in cube_751 / 3375
# Cube_751 is empty.
#
# There are 0 points in cube_752 / 3375
# Cube_752 is empty.
#
# There are 0 points in cube_753 / 3375
# Cube_753 is empty.
#
# There are 0 points in cube_754 / 3375
# Cube_754 is empty.
#
# There are 0 points in cube_755 / 3375
# Cube_755 is empty.
#
# There are 0 points in cube_756 / 3375
# Cube_756 is empty.
#
# There are 0 points in cube_757 / 3375
# Cube_757 is empty.
#
# There are 0 points in cube_758 / 3375
# Cube_758 is empty.
#
# There are 0 points in cube_759 / 3375
# Cube_759 is empty.
#
# There are 0 points in cube_760 / 3375
# Cube_760 is empty.
#
# There are 3 points in cube_761 / 3375
# Found 1 clusters in cube_761
#
# There are 44 points in cube_762 / 3375
# Found 1 clusters in cube_762
#
# There are 684 points in cube_763 / 3375
# Found 3 clusters in cube_763
#
# There are 0 points in cube_764 / 3375
# Cube_764 is empty.
#
# There are 0 points in cube_765 / 3375
# Cube_765 is empty.
#
# There are 0 points in cube_766 / 3375
# Cube_766 is empty.
#
# There are 3 points in cube_767 / 3375
# Found 1 clusters in cube_767
#
# There are 3 points in cube_768 / 3375
# Found 1 clusters in cube_768
#
# There are 0 points in cube_769 / 3375
# Cube_769 is empty.
#
# There are 0 points in cube_770 / 3375
# Cube_770 is empty.
#
# There are 0 points in cube_771 / 3375
# Cube_771 is empty.
#
# There are 2 points in cube_772 / 3375
# Found 1 clusters in cube_772
#
# There are 3 points in cube_773 / 3375
# Found 1 clusters in cube_773
#
# There are 3 points in cube_774 / 3375
# Found 1 clusters in cube_774
#
# There are 4 points in cube_775 / 3375
# Found 1 clusters in cube_775
#
# There are 14 points in cube_776 / 3375
# Found 1 clusters in cube_776
#
# There are 53 points in cube_777 / 3375
# Found 1 clusters in cube_777
#
# There are 687 points in cube_778 / 3375
# Found 3 clusters in cube_778
#
# There are 0 points in cube_779 / 3375
# Cube_779 is empty.
#
# There are 0 points in cube_780 / 3375
# Cube_780 is empty.
#
# There are 288 points in cube_781 / 3375
# Found 2 clusters in cube_781
#
# There are 662 points in cube_782 / 3375
# Found 3 clusters in cube_782
#
# There are 262 points in cube_783 / 3375
# Found 2 clusters in cube_783
#
# There are 47 points in cube_784 / 3375
# Found 1 clusters in cube_784
#
# There are 325 points in cube_785 / 3375
# Found 2 clusters in cube_785
#
# There are 1024 points in cube_786 / 3375
# Found 3 clusters in cube_786
#
# There are 3516 points in cube_787 / 3375
# Found 4 clusters in cube_787
#
# There are 5592 points in cube_788 / 3375
# Found 4 clusters in cube_788
#
# There are 10679 points in cube_789 / 3375
# Found 4 clusters in cube_789
#
# There are 18663 points in cube_790 / 3375
# Found 4 clusters in cube_790
#
# There are 4345 points in cube_791 / 3375
# Found 4 clusters in cube_791
#
# ...
# Cube_3109 is empty.
#
# There are 0 points in cube_3110 / 3375
# Cube_3110 is empty.
#
# There are 0 points in cube_3111 / 3375
# Cube_3111 is empty.
#
# There are 0 points in cube_3112 / 3375
# Cube_3112 is empty.
#
# There are 0 points in cube_3113 / 3375
# Cube_3113 is empty.
#
# There are 0 points in cube_3114 / 3375
# Cube_3114 is empty.
#
# There are 0 points in cube_3115 / 3375
# Cube_3115 is empty.
#
# There are 0 points in cube_3116 / 3375
# Cube_3116 is empty.
#
# There are 0 points in cube_3117 / 3375
# Cube_3117 is empty.
#
# There are 0 points in cube_3118 / 3375
# Cube_3118 is empty.
#
# There are 0 points in cube_3119 / 3375
# Cube_3119 is empty.
#
# There are 0 points in cube_3120 / 3375
# Cube_3120 is empty.
#
# There are 0 points in cube_3121 / 3375
# Cube_3121 is empty.
#
# There are 0 points in cube_3122 / 3375
# Cube_3122 is empty.
#
# There are 0 points in cube_3123 / 3375
# Cube_3123 is empty.
#
# There are 0 points in cube_3124 / 3375
# Cube_3124 is empty.
#
# There are 0 points in cube_3125 / 3375
# Cube_3125 is empty.
#
# There are 0 points in cube_3126 / 3375
# Cube_3126 is empty.
#
# There are 0 points in cube_3127 / 3375
# Cube_3127 is empty.
#
# There are 0 points in cube_3128 / 3375
# Cube_3128 is empty.
#
# There are 0 points in cube_3129 / 3375
# Cube_3129 is empty.
#
# There are 0 points in cube_3130 / 3375
# Cube_3130 is empty.
#
# There are 0 points in cube_3131 / 3375
# Cube_3131 is empty.
#
# There are 0 points in cube_3132 / 3375
# Cube_3132 is empty.
#
# There are 0 points in cube_3133 / 3375
# Cube_3133 is empty.
#
# There are 0 points in cube_3134 / 3375
# Cube_3134 is empty.
#
# There are 0 points in cube_3135 / 3375
# Cube_3135 is empty.
#
# There are 0 points in cube_3136 / 3375
# Cube_3136 is empty.
#
# There are 0 points in cube_3137 / 3375
# Cube_3137 is empty.
#
# There are 0 points in cube_3138 / 3375
# Cube_3138 is empty.
#
# There are 0 points in cube_3139 / 3375
# Cube_3139 is empty.
#
# There are 0 points in cube_3140 / 3375
# Cube_3140 is empty.
#
# There are 0 points in cube_3141 / 3375
# Cube_3141 is empty.
#
# There are 0 points in cube_3142 / 3375
# Cube_3142 is empty.
#
# There are 0 points in cube_3143 / 3375
# Cube_3143 is empty.
#
# There are 0 points in cube_3144 / 3375
# Cube_3144 is empty.
#
# There are 0 points in cube_3145 / 3375
# Cube_3145 is empty.
#
# There are 0 points in cube_3146 / 3375
# Cube_3146 is empty.
#
# There are 0 points in cube_3147 / 3375
# Cube_3147 is empty.
#
# There are 0 points in cube_3148 / 3375
# Cube_3148 is empty.
#
# There are 0 points in cube_3149 / 3375
# Cube_3149 is empty.
#
# There are 0 points in cube_3150 / 3375
# Cube_3150 is empty.
#
# There are 0 points in cube_3151 / 3375
# Cube_3151 is empty.
#
# There are 0 points in cube_3152 / 3375
# Cube_3152 is empty.
#
# There are 0 points in cube_3153 / 3375
# Cube_3153 is empty.
#
# There are 0 points in cube_3154 / 3375
# Cube_3154 is empty.
#
# There are 0 points in cube_3155 / 3375
# Cube_3155 is empty.
#
# There are 0 points in cube_3156 / 3375
# Cube_3156 is empty.
#
# There are 0 points in cube_3157 / 3375
# Cube_3157 is empty.
#
# There are 0 points in cube_3158 / 3375
# Cube_3158 is empty.
#
# There are 0 points in cube_3159 / 3375
# Cube_3159 is empty.
#
# There are 0 points in cube_3160 / 3375
# Cube_3160 is empty.
#
# There are 0 points in cube_3161 / 3375
# Cube_3161 is empty.
#
# There are 0 points in cube_3162 / 3375
# Cube_3162 is empty.
#
# There are 1 points in cube_3163 / 3375
# Found 1 clusters in cube_3163
#
# There are 0 points in cube_3164 / 3375
# Cube_3164 is empty.
#
# There are 0 points in cube_3165 / 3375
# Cube_3165 is empty.
#
# There are 0 points in cube_3166 / 3375
# Cube_3166 is empty.
#
# There are 0 points in cube_3167 / 3375
# Cube_3167 is empty.
#
# There are 0 points in cube_3168 / 3375
# Cube_3168 is empty.
#
# There are 0 points in cube_3169 / 3375
# Cube_3169 is empty.
#
# There are 0 points in cube_3170 / 3375
# Cube_3170 is empty.
#
# There are 0 points in cube_3171 / 3375
# Cube_3171 is empty.
#
# There are 0 points in cube_3172 / 3375
# Cube_3172 is empty.
#
# There are 0 points in cube_3173 / 3375
# Cube_3173 is empty.
#
# There are 0 points in cube_3174 / 3375
# Cube_3174 is empty.
#
# There are 0 points in cube_3175 / 3375
# Cube_3175 is empty.
#
# There are 0 points in cube_3176 / 3375
# Cube_3176 is empty.
#
# There are 0 points in cube_3177 / 3375
# Cube_3177 is empty.
#
# There are 0 points in cube_3178 / 3375
# Cube_3178 is empty.
#
# There are 0 points in cube_3179 / 3375
# Cube_3179 is empty.
#
# There are 0 points in cube_3180 / 3375
# Cube_3180 is empty.
#
# There are 0 points in cube_3181 / 3375
# Cube_3181 is empty.
#
# There are 0 points in cube_3182 / 3375
# Cube_3182 is empty.
#
# There are 0 points in cube_3183 / 3375
# Cube_3183 is empty.
#
# There are 0 points in cube_3184 / 3375
# Cube_3184 is empty.
#
# There are 0 points in cube_3185 / 3375
# Cube_3185 is empty.
#
# There are 0 points in cube_3186 / 3375
# Cube_3186 is empty.
#
# There are 0 points in cube_3187 / 3375
# Cube_3187 is empty.
#
# There are 0 points in cube_3188 / 3375
# Cube_3188 is empty.
#
# There are 0 points in cube_3189 / 3375
# Cube_3189 is empty.
#
# There are 0 points in cube_3190 / 3375
# Cube_3190 is empty.
#
# There are 0 points in cube_3191 / 3375
# Cube_3191 is empty.
#
# There are 0 points in cube_3192 / 3375
# Cube_3192 is empty.
#
# There are 0 points in cube_3193 / 3375
# Cube_3193 is empty.
# There are 0 points in cube_3194 / 3375
# Cube_3194 is empty.
#
# There are 0 points in cube_3195 / 3375
# Cube_3195 is empty.
#
# There are 0 points in cube_3196 / 3375
# Cube_3196 is empty.
#
# There are 0 points in cube_3197 / 3375
# Cube_3197 is empty.
#
# There are 0 points in cube_3198 / 3375
# Cube_3198 is empty.
#
# There are 0 points in cube_3199 / 3375
# Cube_3199 is empty.
#
# There are 0 points in cube_3200 / 3375
# Cube_3200 is empty.
#
# There are 0 points in cube_3201 / 3375
# Cube_3201 is empty.
#
# There are 0 points in cube_3202 / 3375
# Cube_3202 is empty.
#
# There are 0 points in cube_3203 / 3375
# Cube_3203 is empty.
#
# There are 0 points in cube_3204 / 3375
# Cube_3204 is empty.
#
# There are 0 points in cube_3205 / 3375
# Cube_3205 is empty.
#
# There are 0 points in cube_3206 / 3375
# Cube_3206 is empty.
#
# There are 0 points in cube_3207 / 3375
# Cube_3207 is empty.
#
# There are 0 points in cube_3208 / 3375
# Cube_3208 is empty.
#
# There are 0 points in cube_3209 / 3375
# Cube_3209 is empty.
#
# There are 0 points in cube_3210 / 3375
# Cube_3210 is empty.
#
# There are 0 points in cube_3211 / 3375
# Cube_3211 is empty.
#
# There are 0 points in cube_3212 / 3375
# Cube_3212 is empty.
#
# There are 0 points in cube_3213 / 3375
# Cube_3213 is empty.
#
# There are 0 points in cube_3214 / 3375
# Cube_3214 is empty.
#
# There are 0 points in cube_3215 / 3375
# Cube_3215 is empty.
#
# There are 0 points in cube_3216 / 3375
# Cube_3216 is empty.
#
# There are 0 points in cube_3217 / 3375
# Cube_3217 is empty.
#
# There are 0 points in cube_3218 / 3375
# Cube_3218 is empty.
#
# There are 0 points in cube_3219 / 3375
# Cube_3219 is empty.
#
# There are 0 points in cube_3220 / 3375
# Cube_3220 is empty.
#
# There are 0 points in cube_3221 / 3375
# Cube_3221 is empty.
#
# There are 0 points in cube_3222 / 3375
# Cube_3222 is empty.
#
# There are 0 points in cube_3223 / 3375
# Cube_3223 is empty.
#
# There are 0 points in cube_3224 / 3375
# Cube_3224 is empty.
#
# There are 0 points in cube_3225 / 3375
# Cube_3225 is empty.
#
# There are 0 points in cube_3226 / 3375
# Cube_3226 is empty.
#
# There are 0 points in cube_3227 / 3375
# Cube_3227 is empty.
#
# There are 0 points in cube_3228 / 3375
# Cube_3228 is empty.
#
# There are 0 points in cube_3229 / 3375
# Cube_3229 is empty.
#
# There are 0 points in cube_3230 / 3375
# Cube_3230 is empty.
#
# There are 0 points in cube_3231 / 3375
# Cube_3231 is empty.
#
# There are 0 points in cube_3232 / 3375
# Cube_3232 is empty.
#
# There are 0 points in cube_3233 / 3375
# Cube_3233 is empty.
#
# There are 0 points in cube_3234 / 3375
# Cube_3234 is empty.
#
# There are 0 points in cube_3235 / 3375
# Cube_3235 is empty.
#
# There are 0 points in cube_3236 / 3375
# Cube_3236 is empty.
#
# There are 0 points in cube_3237 / 3375
# Cube_3237 is empty.
#
# There are 0 points in cube_3238 / 3375
# Cube_3238 is empty.
#
# There are 0 points in cube_3239 / 3375
# Cube_3239 is empty.
#
# There are 0 points in cube_3240 / 3375
# Cube_3240 is empty.
#
# There are 0 points in cube_3241 / 3375
# Cube_3241 is empty.
#
# There are 0 points in cube_3242 / 3375
# Cube_3242 is empty.
#
# There are 0 points in cube_3243 / 3375
# Cube_3243 is empty.
#
# There are 0 points in cube_3244 / 3375
# Cube_3244 is empty.
#
# There are 0 points in cube_3245 / 3375
# Cube_3245 is empty.
#
# There are 0 points in cube_3246 / 3375
# Cube_3246 is empty.
#
# There are 0 points in cube_3247 / 3375
# Cube_3247 is empty.
#
# There are 0 points in cube_3248 / 3375
# Cube_3248 is empty.
#
# There are 0 points in cube_3249 / 3375
# Cube_3249 is empty.
#
# There are 0 points in cube_3250 / 3375
# Cube_3250 is empty.
#
# There are 0 points in cube_3251 / 3375
# Cube_3251 is empty.
#
# There are 0 points in cube_3252 / 3375
# Cube_3252 is empty.
#
# There are 0 points in cube_3253 / 3375
# Cube_3253 is empty.
#
# There are 0 points in cube_3254 / 3375
# Cube_3254 is empty.
#
# There are 0 points in cube_3255 / 3375
# Cube_3255 is empty.
#
# There are 0 points in cube_3256 / 3375
# Cube_3256 is empty.
#
# There are 0 points in cube_3257 / 3375
# Cube_3257 is empty.
#
# There are 0 points in cube_3258 / 3375
# Cube_3258 is empty.
#
# There are 0 points in cube_3259 / 3375
# Cube_3259 is empty.
#
# There are 0 points in cube_3260 / 3375
# Cube_3260 is empty.
#
# There are 0 points in cube_3261 / 3375
# Cube_3261 is empty.
#
# There are 0 points in cube_3262 / 3375
# Cube_3262 is empty.
#
# There are 0 points in cube_3263 / 3375
# Cube_3263 is empty.
#
# There are 0 points in cube_3264 / 3375
# Cube_3264 is empty.
#
# There are 0 points in cube_3265 / 3375
# Cube_3265 is empty.
#
# There are 0 points in cube_3266 / 3375
# Cube_3266 is empty.
#
# There are 0 points in cube_3267 / 3375
# Cube_3267 is empty.
#
# There are 0 points in cube_3268 / 3375
# Cube_3268 is empty.
#
# There are 0 points in cube_3269 / 3375
# Cube_3269 is empty.
#
# There are 0 points in cube_3270 / 3375
# Cube_3270 is empty.
#
# There are 0 points in cube_3271 / 3375
# Cube_3271 is empty.
#
# There are 0 points in cube_3272 / 3375
# Cube_3272 is empty.
#
# There are 0 points in cube_3273 / 3375
# Cube_3273 is empty.
#
# There are 0 points in cube_3274 / 3375
# Cube_3274 is empty.
#
# There are 0 points in cube_3275 / 3375
# Cube_3275 is empty.
#
# There are 0 points in cube_3276 / 3375
# Cube_3276 is empty.
#
# There are 0 points in cube_3277 / 3375
# Cube_3277 is empty.
#
# There are 0 points in cube_3278 / 3375
# Cube_3278 is empty.
#
# There are 0 points in cube_3279 / 3375
# Cube_3279 is empty.
#
# There are 0 points in cube_3280 / 3375
# Cube_3280 is empty.
#
# There are 0 points in cube_3281 / 3375
# Cube_3281 is empty.
#
# There are 0 points in cube_3282 / 3375
# Cube_3282 is empty.
#
# There are 0 points in cube_3283 / 3375
# Cube_3283 is empty.
#
# There are 0 points in cube_3284 / 3375
# Cube_3284 is empty.
#
# There are 0 points in cube_3285 / 3375
# Cube_3285 is empty.
#
# There are 0 points in cube_3286 / 3375
# Cube_3286 is empty.
#
# There are 0 points in cube_3287 / 3375
# Cube_3287 is empty.
#
# There are 0 points in cube_3288 / 3375
# Cube_3288 is empty.
#
# There are 0 points in cube_3289 / 3375
# Cube_3289 is empty.
#
# There are 0 points in cube_3290 / 3375
# Cube_3290 is empty.
#
# There are 0 points in cube_3291 / 3375
# Cube_3291 is empty.
#
# There are 0 points in cube_3292 / 3375
# Cube_3292 is empty.
#
# There are 0 points in cube_3293 / 3375
# Cube_3293 is empty.
#
# There are 0 points in cube_3294 / 3375
# Cube_3294 is empty.
#
# There are 0 points in cube_3295 / 3375
# Cube_3295 is empty.
#
# There are 0 points in cube_3296 / 3375
# Cube_3296 is empty.
#
# There are 0 points in cube_3297 / 3375
# Cube_3297 is empty.
#
# There are 0 points in cube_3298 / 3375
# Cube_3298 is empty.
#
# There are 0 points in cube_3299 / 3375
# Cube_3299 is empty.
#
# There are 0 points in cube_3300 / 3375
# Cube_3300 is empty.
#
# There are 0 points in cube_3301 / 3375
# Cube_3301 is empty.
#
# There are 0 points in cube_3302 / 3375
# Cube_3302 is empty.
#
# There are 0 points in cube_3303 / 3375
# Cube_3303 is empty.
#
# There are 0 points in cube_3304 / 3375
# Cube_3304 is empty.
#
# There are 0 points in cube_3305 / 3375
# Cube_3305 is empty.
#
# There are 0 points in cube_3306 / 3375
# Cube_3306 is empty.
#
# There are 0 points in cube_3307 / 3375
# Cube_3307 is empty.
#
# There are 0 points in cube_3308 / 3375
# Cube_3308 is empty.
#
# There are 0 points in cube_3309 / 3375
# Cube_3309 is empty.
#
# There are 0 points in cube_3310 / 3375
# Cube_3310 is empty.
#
# There are 0 points in cube_3311 / 3375
# Cube_3311 is empty.
#
# There are 0 points in cube_3312 / 3375
# Cube_3312 is empty.
#
# There are 0 points in cube_3313 / 3375
# Cube_3313 is empty.
#
# There are 0 points in cube_3314 / 3375
# Cube_3314 is empty.
#
# There are 0 points in cube_3315 / 3375
# Cube_3315 is empty.
#
# There are 0 points in cube_3316 / 3375
# Cube_3316 is empty.
#
# There are 0 points in cube_3317 / 3375
# Cube_3317 is empty.
#
# There are 0 points in cube_3318 / 3375
# Cube_3318 is empty.
#
# There are 0 points in cube_3319 / 3375
# Cube_3319 is empty.
#
# There are 0 points in cube_3320 / 3375
# Cube_3320 is empty.
#
# There are 0 points in cube_3321 / 3375
# Cube_3321 is empty.
#
# There are 0 points in cube_3322 / 3375
# Cube_3322 is empty.
#
# There are 0 points in cube_3323 / 3375
# Cube_3323 is empty.
#
# There are 0 points in cube_3324 / 3375
# Cube_3324 is empty.
#
# There are 0 points in cube_3325 / 3375
# Cube_3325 is empty.
#
# There are 0 points in cube_3326 / 3375
# Cube_3326 is empty.
#
# There are 0 points in cube_3327 / 3375
# Cube_3327 is empty.
#
# There are 0 points in cube_3328 / 3375
# Cube_3328 is empty.
#
# There are 0 points in cube_3329 / 3375
# Cube_3329 is empty.
#
# There are 0 points in cube_3330 / 3375
# Cube_3330 is empty.
# There are 0 points in cube_3331 / 3375
# Cube_3331 is empty.
#
# There are 0 points in cube_3332 / 3375
# Cube_3332 is empty.
#
# There are 0 points in cube_3333 / 3375
# Cube_3333 is empty.
#
# There are 0 points in cube_3334 / 3375
# Cube_3334 is empty.
#
# There are 0 points in cube_3335 / 3375
# Cube_3335 is empty.
#
# There are 0 points in cube_3336 / 3375
# Cube_3336 is empty.
#
# There are 0 points in cube_3337 / 3375
# Cube_3337 is empty.
#
# There are 0 points in cube_3338 / 3375
# Cube_3338 is empty.
#
# There are 0 points in cube_3339 / 3375
# Cube_3339 is empty.
#
# There are 0 points in cube_3340 / 3375
# Cube_3340 is empty.
#
# There are 0 points in cube_3341 / 3375
# Cube_3341 is empty.
#
# There are 0 points in cube_3342 / 3375
# Cube_3342 is empty.
#
# There are 0 points in cube_3343 / 3375
# Cube_3343 is empty.
#
# There are 0 points in cube_3344 / 3375
# Cube_3344 is empty.
#
# There are 0 points in cube_3345 / 3375
# Cube_3345 is empty.
#
# There are 0 points in cube_3346 / 3375
# Cube_3346 is empty.
#
# There are 0 points in cube_3347 / 3375
# Cube_3347 is empty.
#
# There are 0 points in cube_3348 / 3375
# Cube_3348 is empty.
#
# There are 0 points in cube_3349 / 3375
# Cube_3349 is empty.
#
# There are 0 points in cube_3350 / 3375
# Cube_3350 is empty.
#
# There are 0 points in cube_3351 / 3375
# Cube_3351 is empty.
#
# There are 0 points in cube_3352 / 3375
# Cube_3352 is empty.
#
# There are 0 points in cube_3353 / 3375
# Cube_3353 is empty.
#
# There are 0 points in cube_3354 / 3375
# Cube_3354 is empty.
#
# There are 0 points in cube_3355 / 3375
# Cube_3355 is empty.
#
# There are 0 points in cube_3356 / 3375
# Cube_3356 is empty.
#
# There are 0 points in cube_3357 / 3375
# Cube_3357 is empty.
#
# There are 0 points in cube_3358 / 3375
# Cube_3358 is empty.
#
# There are 0 points in cube_3359 / 3375
# Cube_3359 is empty.
#
# There are 0 points in cube_3360 / 3375
# Cube_3360 is empty.
#
# There are 0 points in cube_3361 / 3375
# Cube_3361 is empty.
#
# There are 0 points in cube_3362 / 3375
# Cube_3362 is empty.
#
# There are 0 points in cube_3363 / 3375
# Cube_3363 is empty.
#
# There are 0 points in cube_3364 / 3375
# Cube_3364 is empty.
#
# There are 0 points in cube_3365 / 3375
# Cube_3365 is empty.
#
# There are 0 points in cube_3366 / 3375
# Cube_3366 is empty.
#
# There are 0 points in cube_3367 / 3375
# Cube_3367 is empty.
#
# There are 0 points in cube_3368 / 3375
# Cube_3368 is empty.
#
# There are 0 points in cube_3369 / 3375
# Cube_3369 is empty.
#
# There are 0 points in cube_3370 / 3375
# Cube_3370 is empty.
#
# There are 0 points in cube_3371 / 3375
# Cube_3371 is empty.
#
# There are 0 points in cube_3372 / 3375
# Cube_3372 is empty.
#
# There are 0 points in cube_3373 / 3375
# Cube_3373 is empty.
#
# There are 0 points in cube_3374 / 3375
# Cube_3374 is empty.
#
#
# Created 1501 edges and 473 nodes in 0:06:53.249353.

# %% [markdown]
# ### standard algorithm will most likely fill node color with red if there is any fraud transaction in it

# %%
colormap = np.ones_like(labels)
for node, indices in graph['nodes'].items():
    node_labels = mapper.data_from_cluster_id(node, graph, labels)
    #assert(np.allclose(ytrain[indices], node_labels))
    #print(fraud_mean)
    fraud_mean = 1.0
    if np.any(node_labels > 0):
        fraud_mean = 0.0
    #fraud_mean = (1.0 - (node_labels > 0).mean())**4
    #fraud_size = node_labels.size
    #tooltip_s.append((fraud_size, fraud_mean))
    colormap[indices] = fraud_mean

#tooltip_s = ytrain.copy()
#tooltip_s = np.array(tooltip_s)

# %% [markdown]
# ### Tooltips will indicate if there are any false positives or true fraud

# %%
custom_tooltips = np.array(['']*len(labels), dtype=object)
custom_tooltips[labels == 0] = 'fp'
custom_tooltips[labels == 1] = 'FRAUD'

# %%
html = mapper.visualize(graph,
                 path_html="mean_pca_with_isof.html",
                 projected_X=proj_3d, color_function=colormap,
                 projected_X_names=['pca_mean_1', 'pca_mean_2', 'isof_score'], custom_tooltips = custom_tooltips,#10**(labels + 1),
                 title="mean_pca_with_isof(n_samples={})".format(len(baseamount_agg_mean_values)))
# Out:
# /home/const.belev/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# Wrote visualization to: mean_pca_with_isof.html

# %%
display("mean_pca_with_isof.html")
# Out:
# <iframe src=mean_pca_with_isof.html width=100%% height=800 frameBorder="0"></iframe>

# %%
# !pwd
# Out:
# /home/yanina/TDA
